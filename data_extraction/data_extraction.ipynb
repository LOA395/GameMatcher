# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd
from time import sleep
import random
from extraction_functions import *

# %%
# Ejecutar la función para obtener 1000 juegos válidos
df_juegos_completo = obtener_juegos_aleatorios(cantidad_deseada=10000, rango_min=1, rango_max=300000, pause_time=1)

# Guardar el DataFrame en un archivo CSV
df_juegos_completo.to_csv('boardgames_10000_juegos.csv', index=False)
# Out:
# Juego encontrado: 81305, Total juegos obtenidos: 1
# Juego encontrado: 230726, Total juegos obtenidos: 2
# Juego encontrado: 43420, Total juegos obtenidos: 3
# Juego encontrado: 109024, Total juegos obtenidos: 4
# Juego encontrado: 208284, Total juegos obtenidos: 5
# Juego encontrado: 61919, Total juegos obtenidos: 6
# Juego encontrado: 42701, Total juegos obtenidos: 7
# Juego encontrado: 270848, Total juegos obtenidos: 8
# Juego encontrado: 236045, Total juegos obtenidos: 9
# Juego encontrado: 31672, Total juegos obtenidos: 10
# Juego encontrado: 19515, Total juegos obtenidos: 11
# Juego encontrado: 49430, Total juegos obtenidos: 12
# Juego encontrado: 59995, Total juegos obtenidos: 13
# Juego encontrado: 18363, Total juegos obtenidos: 14
# Juego encontrado: 239484, Total juegos obtenidos: 15
# Juego encontrado: 49080, Total juegos obtenidos: 16
# Juego encontrado: 177956, Total juegos obtenidos: 17
# Juego encontrado: 143770, Total juegos obtenidos: 18
# ...

# %%
df_juegos_completo = pd.read_csv('boardgames_10000_juegos.csv')

# %%
df_juegos_completo.sample(30)
# Out:
#       BGGId                                               Name  \
# 143  179043                   Cry Havoc! (Issue 15 - Jul 2007)
# 526  105823                           AGL: Starlight Sacrifice
# 593   35442                                            Ta & Ge
# 482   31700                              The Alaskan Gold Rush
# 385  187320                                Realms of Adventure
# 199  158010              Space Pirates (Multiverse Adventures)
# 941  222890                         Cleric/Oracle Spells (3PP)
# 934  223327                                   Someone Has Died
# 816  269555                         Touched: A Darkening Alley
# 566   13384                                       Election USA
# 447  152464                               Par Terre et Par Mer
# 182  272859                Barovia 1: Hearing Secret Harmonies
# 548   22276                     Combat Team: The Captains' War
# 606  136809                                        Shark Cards
# ...
